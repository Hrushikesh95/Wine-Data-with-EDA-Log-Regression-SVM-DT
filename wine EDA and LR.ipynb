# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv('Data set/wine_data.csv')

# %%
train.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      0    14.23        1.71  2.43               15.6        127
# 1      0    13.20        1.78  2.14               11.2        100
# 2      0    13.16        2.36  2.67               18.6        101
# 3      0    14.37        1.95  2.50               16.8        113
# 4      0    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315  Proline
# 0             5.64  1.04         3.92     1065
# 1             4.38  1.05         3.40     1050
# ...

# %%
train.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     0.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      0.000000   11.030000    0.740000    1.360000          10.600000
# 25%      0.000000   12.362500    1.602500    2.210000          17.200000
# 50%      1.000000   13.050000    1.865000    2.360000          19.500000
# 75%      2.000000   13.677500    3.082500    2.557500          21.500000
# max      2.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
train.isnull()
# Out:
#      Class  Alcohol  Malic acid    Ash  Alcalinity of ash  Magnesium  \
# 0    False    False       False  False              False      False
# 1    False    False       False  False              False      False
# 2    False    False       False  False              False      False
# 3    False    False       False  False              False      False
# 4    False    False       False  False              False      False
# ..     ...      ...         ...    ...                ...        ...
# 173  False    False       False  False              False      False
# 174  False    False       False  False              False      False
# 175  False    False       False  False              False      False
# 176  False    False       False  False              False      False
# 177  False    False       False  False              False      False
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Class                 178 non-null    int64
#  1   Alcohol               178 non-null    float64
#  2   Malic acid            178 non-null    float64
#  3   Ash                   178 non-null    float64
#  4   Alcalinity of ash     178 non-null    float64
#  5   Magnesium             178 non-null    int64
#  6   Total phenols         178 non-null    float64
#  7   Flavanoids            178 non-null    float64
#  8   Nonflavanoid phenols  178 non-null    float64
#  9   Proanthocyanins       178 non-null    float64
#  10  Color intensity       178 non-null    float64
#  11  Hue                   178 non-null    float64
#  12  OD280/OD315           178 non-null    float64
#  13  Proline               178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='plasma')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Class',data=train)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
plt.figure(figsize=(15, 7))
sns.set_style('whitegrid')
sns.countplot(x='Class',hue='Alcohol',data=train,palette='seismic')
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
plt.figure(figsize=(15, 7))
sns.set_style('whitegrid')
sns.countplot(x='Class',hue='Magnesium',data=train,palette='Spectral')
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
plt.figure(figsize=(15, 7))
sns.set_style('whitegrid')
sns.countplot(x='Class',hue='Ash',data=train,palette='Spectral')
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
plt.figure(figsize=(15, 7))
sns.countplot(x='Proline',data=train)
# Out:
# <AxesSubplot:xlabel='Proline', ylabel='count'>

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Class',y='Ash',data=train,palette='summer')
# Out:
# <AxesSubplot:xlabel='Class', ylabel='Ash'>

# %%
train.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      0    14.23        1.71  2.43               15.6        127
# 1      0    13.20        1.78  2.14               11.2        100
# 2      0    13.16        2.36  2.67               18.6        101
# 3      0    14.37        1.95  2.50               16.8        113
# 4      0    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315  Proline
# 0             5.64  1.04         3.92     1065
# 1             4.38  1.05         3.40     1050
# ...

# %%
#LOGISTIC REGRESSION
#Train Test Split here x is considered as below
train.drop('Class',axis=1).head()
# Out:
#    Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0    14.23        1.71  2.43               15.6        127           2.80
# 1    13.20        1.78  2.14               11.2        100           2.65
# 2    13.16        2.36  2.67               18.6        101           2.80
# 3    14.37        1.95  2.50               16.8        113           3.85
# 4    13.24        2.59  2.87               21.0        118           2.80
#
#    Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280/OD315  Proline
# 0         3.92     1065
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(train.drop('Class',axis=1), 
                                                    train['Class'], test_size=0.30, 
                                                    random_state=101)

# %%
#training and predicting
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\Hrushi\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
accuracy=confusion_matrix(y_test,predictions)

# %%
accuracy
# Out:
# array([[18,  1,  0],
#        [ 1, 20,  1],
#        [ 0,  1, 12]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(y_test,predictions)
accuracy
# Out:
# 0.9259259259259259

# %%
#evaluation
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        19
#            1       0.91      0.91      0.91        22
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.93        54
#    macro avg       0.93      0.93      0.93        54
# weighted avg       0.93      0.93      0.93        54
